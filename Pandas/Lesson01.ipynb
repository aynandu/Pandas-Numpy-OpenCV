# %%
import pandas as pd

# %%
#handiling Na values
na_vals = ['NA','Missing']
#Read a CSV file As a data frame with index 
df=pd.read_csv('C:/Users/nandu/Desktop/Pandas_Numpy_OpenCV/Data/DataSet/survey_results_public.csv',na_values=na_vals)


#Also write like this below
# df=pd.read_csv('C:/Users/nandu/Desktop/Pandas_Numpy_OpenCV/Data/DataSet/survey_results_public.csv',index_col='Respondent')

# %%
df

# %%
df.shape , df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
#set option. how to dispaly
pd.set_option('display.max_columns',85)

# %%
schema_df=pd.read_csv('C:/Users/nandu/Desktop/Pandas_Numpy_OpenCV/Data/DataSet/survey_results_schema.csv',index_col='Column')

# %%
#First 10 Rows
schema_df.head(10)  
# Last 10 Rows
schema_df.tail(10)
# Out:
#                                                     QuestionText
# Column
# WelcomeChange  Compared to last year, how welcome do you feel...
# SONewContent   Would you like to see any of the following on ...
# Age            What is your age (in years)? If you prefer not...
# Gender         Which of the following do you currently identi...
# Trans                            Do you identify as transgender?
# Sexuality      Which of the following do you currently identi...
# Ethnicity      Which of the following do you identify as? Ple...
# Dependents     Do you have any dependents (e.g., children, el...
# SurveyLength   How do you feel about the length of the survey...
# SurveyEase     How easy or difficult was this survey to compl...

# %%
schema_df.iloc[2] , df['Hobbyist'].value_counts()
# Out:
# (QuestionText    Do you code as a hobby?
#  Name: Hobbyist, dtype: object,
#  Hobbyist
#  Yes    71257
#  No     17626
#  Name: count, dtype: int64)

# %%
#First 3 have a hobby of Coding , Lest find out
df.loc[0:5,'Hobbyist':'Employment'] #This Method Called Slicing
# Out:
#   Hobbyist                 OpenSourcer  \
# 0      Yes                       Never
# 1       No     Less than once per year
# 2      Yes                       Never
# 3       No                       Never
# 4      Yes  Once a month or more often
# 5      Yes                       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
# 5  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
# 5                      Employed full-time

# %%
df.set_index('Respondent',inplace=True)

# %%
#First 3 have a hobby of Coding , Lest find out
#df.loc[0:5,'Hobbyist':'Employment'] #This Method Called Slicing
#KeyError

# %%
schema_df
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
schema_df.loc['MgrIdiot','QuestionText'],schema_df.loc['MgrIdiot']
# Out:
# ('How confident are you that your manager knows what they’re doing?',
#  QuestionText    How confident are you that your manager knows ...
#  Name: MgrIdiot, dtype: object)

# %%
schema_df.sort_index(ascending=False)# if sort_idex(inplace is true) the schema_df defaulty affect the sorting else,not
# Out:
#                                                     QuestionText
# Column
# YearsCodePro   How many years have you coded professionally (...
# YearsCode      Including any education, how many years have y...
# WorkWeekHrs     On average, how many hours per week do you work?
# WorkRemote                       How often do you work remotely?
# WorkPlan                 How structured or planned is your work?
# ...                                                          ...
# BlockchainOrg  How is your organization thinking about or imp...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BetterLife     Do you think people born today will have a bet...
# Age1stCode     At what age did you write your first line of c...
# Age            What is your age (in years)? If you prefer not...
#
# [85 rows x 1 columns]

# %% [markdown]
# Filter Example

# %%
high_salary = (df['ConvertedComp']>70000)

# %%
df.loc[high_salary,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries=['united States','India','United Kingdom','Germany','Canada']
filt=df['Country'].isin(countries)

# %%
df.loc[filt,'Country']
# Out:
# Respondent
# 1        United Kingdom
# 6                Canada
# 8                 India
# 10                India
# 12               Canada
#               ...
# 84539    United Kingdom
# 85182            Canada
# 85961    United Kingdom
# 86012             India
# 88377            Canada
# Name: Country, Length: 24059, dtype: object

# %%
filt2=df['LanguageWorkedWith'].str.contains('Python', na=False) #na is NaN ie 'Not a Number' / No value /value is not defined
#String in that column does it contain Python

# %%
df.loc[filt2,'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
# Sorting
# =

# %%
df.sort_values(by='Country',inplace=True)

# %%
df.sort_values(by=['Country','ConvertedComp'],ascending=[False,True],inplace=True)

# %%
df[['Country','ConvertedComp']].head(50)
# Out:
#              Country  ConvertedComp
# Respondent
# 47247       Zimbabwe          900.0
# 6492        Zimbabwe         6000.0
# 30743       Zimbabwe         7800.0
# 84155       Zimbabwe        12000.0
# 35092       Zimbabwe        12000.0
# 54422       Zimbabwe        15000.0
# 1886        Zimbabwe        18000.0
# 2530        Zimbabwe        19200.0
# 66459       Zimbabwe        24000.0
# 82752       Zimbabwe        28800.0
# 15930       Zimbabwe        30000.0
# 15299       Zimbabwe        42000.0
# 83850       Zimbabwe        45000.0
# 76594       Zimbabwe        70000.0
# 55405       Zimbabwe       180000.0
# 22363       Zimbabwe            NaN
# 3991        Zimbabwe            NaN
# 64719       Zimbabwe            NaN
# 53047       Zimbabwe            NaN
# 22975       Zimbabwe            NaN
# 11057       Zimbabwe            NaN
# 21968       Zimbabwe            NaN
# 251         Zimbabwe            NaN
# 69495       Zimbabwe            NaN
# ...

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 2940     2000000.0
# 3133     2000000.0
# 78960    2000000.0
# 3120     2000000.0
# 78853    2000000.0
# 87410    2000000.0
# 17802    2000000.0
# 17811    2000000.0
# 3848     2000000.0
# 17056    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10,'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 2940        I am a developer by profession      Yes
# 3133        I am a developer by profession      Yes
# 78960       I am a developer by profession      Yes
# 3120        I am a developer by profession      Yes
# 78853       I am a developer by profession       No
# 87410       I am a developer by profession       No
# 17802       I am a developer by profession       No
# 17811       I am a developer by profession       No
# 3848        I am a developer by profession      Yes
# 17056       I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 2940                                                    Never
# 3133                                                    Never
# 78960                                 Less than once per year
# 3120                                  Less than once per year
# ...

# %% [markdown]
# Grouping And Aggregating Data - Analyzing and Exploring Your Data
# =

# %% [markdown]
# * Mean, Median , Mode is the aggregating Functions

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
#df.median() --> ValueError: could not convert string to float
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
#by Percentage
df['SocialMedia'].value_counts(normalize=True)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Saint Vincent and the Grenadines        1
# Saint Kitts and Nevis                   1
# Papua New Guinea                        1
# Dominica                                1
# Niger                                   1
# Name: count, Length: 179, dtype: int64

# %% [markdown]
# Grouping
# =

# %%
country_grp=df.groupby(['Country'])

# %%
country_grp.get_group('India').head(2)
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 66925       I am a developer by profession       No
# 12747       I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 66925                                 Less than once per year
# 12747       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 66925       OSS is, on average, of HIGHER quality than pro...
# 12747       The quality of OSS and closed source software ...
#
#                     Employment Country         Student  \
# Respondent
# 66925       Employed full-time   India  Yes, full-time
# 12747       Employed full-time   India  Yes, full-time
#
#                                              EdLevel  \
# Respondent
# 66925       Bachelor’s degree (BA, BS, B.Eng., etc.)
# 12747       Bachelor’s degree (BA, BS, B.Eng., etc.)
#
# ...

# %% [markdown]
# same reponds Using Filter also
# * filt=df['country']=='India'
# * df.loc[filt]

# %%
#By Filter
filt=df['Country']=='India'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# WeChat 微信                      5
# Hello                          5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
#By Grouping
country_grp['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
country_grp['ConvertedComp'].median().loc['India']
# Out:
# 10080.0

# %%
#aggration Function
country_grp['ConvertedComp'].agg(['median','mean']).loc['India']
# Out:
# median    10080.000000
# mean      28057.664916
# Name: India, dtype: float64

# %%
#Filter Method
filt=df['Country']=='India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].apply(lambda x : x.str.contains('Python').sum()).value_counts(normalize=True)
# Out:
# LanguageWorkedWith
# 1      0.106145
# 0      0.094972
# 8      0.039106
# 2      0.039106
# 3      0.033520
#          ...
# 457    0.005587
# 625    0.005587
# 22     0.005587
# 120    0.005587
# 78     0.005587
# Name: proportion, Length: 93, dtype: float64

# %%
country_repondents=df['Country'].value_counts()
country_repondents
# Out:
# Country
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Saint Vincent and the Grenadines        1
# Saint Kitts and Nevis                   1
# Papua New Guinea                        1
# Dominica                                1
# Niger                                   1
# Name: count, Length: 179, dtype: int64

# %%
country_uses_python=country_grp['LanguageWorkedWith'].apply(lambda x : x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df=pd.concat([country_repondents,country_uses_python],axis='columns',sort=False)
python_df
# Out:
#                                   count  LanguageWorkedWith
# Country
# United States                     20949               10083
# India                              9061                3105
# Germany                            5866                2451
# United Kingdom                     5737                2384
# Canada                             3395                1558
# ...                                 ...                 ...
# Saint Vincent and the Grenadines      1                   0
# Saint Kitts and Nevis                 1                   0
# Papua New Guinea                      1                   0
# Dominica                              1                   1
# Niger                                 1                   1
#
# [179 rows x 2 columns]

# %%
#Rename Columns
python_df.rename(columns={'count':'NumRespondents','LanguageWorkedWith':'NumKnowsPython'},inplace=True)

# %%
#NewColumn
python_df['PctKnowsPython'] = (python_df['NumKnowsPython'] / python_df['NumRespondents'])*100
python_df
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Country
# United States                              20949           10083
# India                                       9061            3105
# Germany                                     5866            2451
# United Kingdom                              5737            2384
# Canada                                      3395            1558
# ...                                          ...             ...
# Saint Vincent and the Grenadines               1               0
# Saint Kitts and Nevis                          1               0
# Papua New Guinea                               1               0
# Dominica                                       1               1
# Niger                                          1               1
#
#                                   PctKnowsPython
# Country
# United States                          48.131176
# India                                  34.267741
# ...

# %%
python_df.sort_values(by='PctKnowsPython',ascending=False,inplace=True)
python_df
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Country
# Niger                                          1               1
# Dominica                                       1               1
# Sao Tome and Principe                          1               1
# Timor-Leste                                    1               1
# Turkmenistan                                   7               6
# ...                                          ...             ...
# Liberia                                        2               0
# Malawi                                         2               0
# Lao People's Democratic Republic               3               0
# Cape Verde                                     3               0
# Gabon                                          2               0
#
#                                   PctKnowsPython
# Country
# Niger                                 100.000000
# Dominica                              100.000000
# ...

# %%
python_df.loc['India']
# Out:
# NumRespondents    9061.000000
# NumKnowsPython    3105.000000
# PctKnowsPython      34.267741
# Name: India, dtype: float64

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 47247     4
# 6492     16
# 30743     6
# 84155     5
# 35092     7
# 54422     3
# 1886     11
# 2530      5
# 66459     9
# 82752    14
# Name: YearsCode, dtype: object

# %% [markdown]
# dtype Converting Error
# ==
# df['YearsCode']=df['YearsCode'].astype(float)
# ### Unexpected error
# ### ValueError: could not convert string to float: 'Less than 1 year'

# %%
df['YearsCode'].unique()  # show all the Values
# Out:
# array(['4', '16', '6', '5', '7', '3', '11', '9', '14', '27', '13', '10',
#        '8', '2', nan, '1', '15', 'Less than 1 year', '12',
#        'More than 50 years', '32', '17', '23', '19', '25', '26', '33',
#        '20', '30', '40', '22', '18', '35', '21', '29', '39', '24', '34',
#        '50', '42', '31', '43', '38', '44', '37', '41', '45', '47', '36',
#        '46', '28', '48', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)
df['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array([ 4., 16.,  6.,  5.,  7.,  3., 11.,  9., 14., 27., 13., 10.,  8.,
#         2., nan,  1., 15.,  0., 12., 51., 32., 17., 23., 19., 25., 26.,
#        33., 20., 30., 40., 22., 18., 35., 21., 29., 39., 24., 34., 50.,
#        42., 31., 43., 38., 44., 37., 41., 45., 47., 36., 46., 28., 48.,
#        49.])

# %%
df['YearsCode']=df['YearsCode'].astype(float)
print(f"Mean : {df['YearsCode'].mean()}\nMedian : {df['YearsCode'].median()}\nMode : {df['YearsCode'].mode()}")
# Out:
# Mean : 11.662114216834588
# Median : 9.0
# Mode : 0    5.0
# Name: YearsCode, dtype: float64
